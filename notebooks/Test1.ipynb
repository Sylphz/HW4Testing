# %%
from random import randint
r = randint(1,100)
r
# Out:
# 42

# %%
for i in range(20):
    r = randint(1,100)
    print(r)
# Out:
# 86
# 51
# 42
# 14
# 8
# 29
# 95
# 68
# 45
# 16
# 4
# 6
# 3
# 55
# 34
# 16
# 88
# 100
# 91
# 98

# %%
N=10
total = 0
for n in range(1,N+1):
    total+=n
total
# Out:
# 55

# %%
N=input("please enter N (integer):")
# Out:
# please enter N (integer):10

# %%
N
# Out:
# '10'

# %%
num = int(N.strip())
for n in range(1,num+1):
    total+=n
total
# Out:
# 110

# %%
board_size=8
board_size_p=board_size+1

# %%
for n in range(8):
    print(" ---"*board_size)
    print("|   "*board_size_p)
print(" ---"*board_size)
# Out:
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- ---

# %%
N=input("Please enter boardsize : ")
board_size = int(n.strip())
num = int(N.strip())
# Out:
# Please enter boardsize : 8
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-4d9cf602a0fc> in <module>()
#       1 N=input("Please enter boardsize : ")
# ----> 2 board_size = int(n.strip())
#       3 num = int(N.strip())
#
# AttributeError: 'int' object has no attribute 'strip'

# %%
def print_board(board_size):
    board_size_plus=board_size+1
    
    for n in range(board_size):
        print(" ---"*board_size)
        print("|   "*board_size_p)
    print(" ---"*board_size)
